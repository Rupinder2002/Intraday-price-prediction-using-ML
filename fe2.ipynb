# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv("/home/devendra/Downloads/train_ctrUa4K.csv",header=0)

# %%
data.dropna(axis=0)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
puredata=data.dropna(axis=0)
puredata


def gender_int(df):
    if df=="Male":
        return 1
    else:
        return 0
    
puredata["Gender"]= puredata["Gender"].map(gender_int)
puredata
new= puredata

# %%
def educated_int(df):
    
    if df=="Graduate":
        return 1
    else:
        return 0
puredata["Education"]= new["Education"].map(educated_int)
puredata
# Out:
#       Loan_ID  Gender Married Dependents  Education Self_Employed  \
# 1    LP001003       1     Yes          1          1            No
# 2    LP001005       1     Yes          0          1           Yes
# 3    LP001006       1     Yes          0          0            No
# 4    LP001008       1      No          0          1            No
# 5    LP001011       1     Yes          2          1           Yes
# ..        ...     ...     ...        ...        ...           ...
# 609  LP002978       0      No          0          1            No
# 610  LP002979       1     Yes         3+          1            No
# 611  LP002983       1     Yes          1          1            No
# 612  LP002984       1     Yes          2          1            No
# 613  LP002990       0      No          0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
def married_int(df):
    if df=="Yes":
        return 1
    else:
        return 0

puredata["Married"]= new["Married"].map(married_int)
puredata
# Out:
#       Loan_ID  Gender  Married Dependents  Education Self_Employed  \
# 1    LP001003       1        1          1          1            No
# 2    LP001005       1        1          0          1           Yes
# 3    LP001006       1        1          0          0            No
# 4    LP001008       1        0          0          1            No
# 5    LP001011       1        1          2          1           Yes
# ..        ...     ...      ...        ...        ...           ...
# 609  LP002978       0        0          0          1            No
# 610  LP002979       1        1         3+          1            No
# 611  LP002983       1        1          1          1            No
# 612  LP002984       1        1          2          1            No
# 613  LP002990       0        0          0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
def self_employed_int(df):
    if df=="Yes":
        return 1
    else:
        return 0

puredata["Self_Employed"]= new["Self_Employed"].map(self_employed_int)
puredata
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1         3+          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
def property_int(df):
    if df=="Urban":
        return 2
    elif df=="Semiurban":
        return 1
    else:
        return 0
    
puredata["Property_Area"]= new["Property_Area"].map(property_int)
puredata
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1         3+          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
def dependent_int(df):
    if df=='3+':
        return 4
    else:
        return float(df)
    
puredata["Dependents"]= new["Dependents"].map(dependent_int)
puredata
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 1    LP001003       1        1         1.0          1              0
# 2    LP001005       1        1         0.0          1              1
# 3    LP001006       1        1         0.0          0              0
# 4    LP001008       1        0         0.0          1              0
# 5    LP001011       1        1         2.0          1              1
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0         0.0          1              0
# 610  LP002979       1        1         4.0          1              0
# 611  LP002983       1        1         1.0          1              0
# 612  LP002984       1        1         2.0          1              0
# 613  LP002990       0        0         0.0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
##data visualisation##
temp=puredata
tempmin=puredata["ApplicantIncome"].min()
tempmax=puredata["ApplicantIncome"].max()
temp["ApplicantIncome"]=puredata["ApplicantIncome"].apply(lambda x: (x/(tempmax-tempmin)))
tempmin=puredata["CoapplicantIncome"].min()
tempmax=puredata["CoapplicantIncome"].max()
temp["CoapplicantIncome"]=puredata["CoapplicantIncome"].apply(lambda x: (x/(tempmax-tempmin)))
tempmin=puredata["LoanAmount"].min()
tempmax=puredata["LoanAmount"].max()
temp["LoanAmount"]=puredata["LoanAmount"].apply(lambda x: (x/(tempmax-tempmin)))
tempmin=puredata["Loan_Amount_Term"].min()
tempmax=puredata["Loan_Amount_Term"].max()
temp["Loan_Amount_Term"]=puredata["Loan_Amount_Term"].apply(lambda x: (x/(tempmax-tempmin)))
tempmin=puredata["Property_Area"].min()
tempmax=puredata["Property_Area"].max()
temp["Property_Area"]=puredata["Property_Area"].apply(lambda x: (x/(tempmax-tempmin)))

tempmin=puredata["Dependents"].min()
tempmax=puredata["Dependents"].max()
temp["Dependents"]=puredata["Dependents"].apply(lambda x: (x/(tempmax-tempmin)))


visualdata= temp.drop(["Loan_ID","Loan_Status"], axis=1)

mean= visualdata.mean(axis=0)
index=visualdata.columns
c=visualdata
for ind in index:
    c[ind]= visualdata[ind].apply(lambda x: x-mean[ind])
#finding covariance matrix#
arr= np.array(c)
arr2= arr.transpose()

covariance= np.dot(arr2,arr)
#### yeah, done with covariance matrix#####

#####finding eigenvaluesa nd eigen vetors#######
#mat= np.array([1,2,3,-4])
#mat=mat.reshape(2,2)
#e,v= np.linalg.eig(mat)
#e, v

e,v= np.linalg.eig(covariance)
#print(e,"  \n------------------------------------ \n", v)

df= pd.DataFrame([e,v]).transpose()
df.columns=(["EigenValue","EigenVector"])
dfs=df.set_index('EigenValue')
dfsorted=dfs.sort_index(ascending=False)
#dfsorted
#calculate v #####

v= np.array(dfsorted["EigenVector"])
vs= np.zeros((len(v),len(v)))
cs= np.zeros((len(v),len(v)))
cs
#vs[:,0]= v[0]
#vs[:,1]=v[1]
it=0;
for i in v:
        vs[:,it]=i
        cs[it]=e
        it=it+1     
csdiag=(np.diag(np.diag(cs)))
#print(e)
#print(csdiag)
#vs is done
vstrans= vs.transpose()
#vs transpose is also there now
#now getteing c diagnoal matrix is also done
Dtemp= np.dot(vstrans,csdiag)
D= np.dot(Dtemp,vs)
#Now lets calculate the commulative energy content of each eigenvector
diagEnergy= e
diagEnergyCom= e
sum1=0
for i in range(len(diagEnergy)):
    sum1=sum1+diagEnergy[i]
    diagEnergyCom[i]=sum1
#commulative energies calculated
#print(diagEnergyCom)
#finding PC1 and PC2
#print(diagEnergyCom)
copyEnergy=diagEnergyCom
#maxloc1= np.argmax(diagEnergyCom)
#diagEnergyCom[maxloc1]=-9999999
#print(diagEnergyCom)
#maxloc2= np.argmax(diagEnergyCom)

#maxloc1,maxloc2
print("information contained= ", 100*((diagEnergyCom[1])/diagEnergyCom[len(diagEnergyCom)-1]),"%")

print("PC1: ",vs[:,0],"\nPC2: ",vs[:,1])
transformation_mat= np.array(vs[:,0])
transformation_mat=np.append(transformation_mat,vs[:,1],axis=0)
transformation_mat=np.array(transformation_mat)
#print(transformation_mat)
transformation_mat=np.reshape(transformation_mat,(2,11))
#print(transformation_mat.shape)
#print(visualdata.shape)
#print(transformation_mat)
#print(visualdata)
########################################################################################################
########################################################################################################


#vd= visualdata.values
graph=temp.groupby("Loan_Status")
graphNo= graph.get_group('N')
graphYes= graph.get_group('Y')
print(graphNo)
print(graphYes)
#######################################################################################################
#graphing
gno=graphNo.drop(["Loan_ID","Loan_Status"],axis=1)
gyes=graphYes.drop(["Loan_ID","Loan_Status"],axis=1)
rdf= np.dot(vd,gno.transpose())
fig = plt.figure().ipynb_checkpoints

ax.scatter(gno[:,0], gno[:,1], alpha=0.8, c='green', edgecolors='none', s=30, label='NO')
ax.scatter(gyes[:,0], gyes[:,1], alpha=0.8, c='red', edgecolors='none', s=30, label='YES')


#print(rdf[:,0])
#import matplotlib.pyplot as plt
#plt.scatter(rdf[:,0],rdf[:,1], alpha=0.5)
# Out:
# information contained=  42.066322698739626 %
# PC1:  [-0.45396996 -0.11136367  0.0102881  -0.17834435  0.84942259  0.1540813
#   0.05214819 -0.00986515  0.02748903  0.01312395 -0.02433994]
# PC2:  [-0.83623427  0.09146028 -0.03085492  0.0658248  -0.4343744  -0.03789505
#   0.30810923  0.01037     0.01290454  0.00826693 -0.0408838 ]
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 1    LP001003       1        1        0.25          1              0
# 7    LP001014       1        1        1.00          1              0
# 9    LP001020       1        1        0.25          1              0
# 13   LP001029       1        0        0.00          1              0
# 17   LP001036       0        0        0.00          1              0
# ..        ...     ...      ...         ...        ...            ...
# 585  LP002912       1        1        0.25          1              0
# 589  LP002926       1        1        0.50          1              1
# ...

# %%
train= puredata.sample(frac=0.8,random_state=100)
train=train.sort_index()
train
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 2    LP001005       1        1         0.0          1              1
# 4    LP001008       1        0         0.0          1              0
# 6    LP001013       1        1         0.0          0              0
# 7    LP001014       1        1         4.0          1              0
# 8    LP001018       1        1         2.0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 607  LP002964       1        1         2.0          0              0
# 608  LP002974       1        1         0.0          1              0
# 609  LP002978       0        0         0.0          1              0
# 610  LP002979       1        1         4.0          1              0
# 613  LP002990       0        0         0.0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
test= puredata.drop(train.index,axis=0)
test=test.sort_index

# %%
X_test= test.drop(["Loan_Status","Loan_ID"],axis=1)
Y_test= test.Loan_Status
X_test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-79541f07321e> in <module>
# ----> 1 X_test= test.drop(["Loan_Status","Loan_ID"],axis=1)
#       2 Y_test= test.Loan_Status
#       3 X_test
#
# AttributeError: 'function' object has no attribute 'drop'

# %%
X_train= train.drop(["Loan_Status","Loan_ID"],axis=1)
print(X_train.to_string())
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Property_Area
# 2         1        1         0.0          1              1         0.037106           0.000000    0.111675          0.810811             1.0            1.0
# 4         1        0         0.0          1              0         0.074212           0.000000    0.238579          0.810811             1.0            1.0
# 6         1        1         0.0          0              0         0.028856           0.044803    0.160745          0.810811             1.0            1.0
# 7         1        1         4.0          1              0         0.037551           0.074002    0.267343          0.810811             0.0            0.5
# 8         1        1         2.0          1              0         0.049549           0.045099    0.284264          0.810811             1.0            1.0
# ...

# %%
Y_train= np.ravel(train.Loan_Status)

# %%
Y_train
# Out:
# array(['Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'N', 'Y',
#        'Y', 'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y',
#        'N', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'N',
#        'Y', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
# ...

# %%
#using svm


from sklearn.svm import SVC 
svm_model = SVC(kernel = 'linear', C = 1).fit(X_train, Y_train) 
svm_predictions = svm_model.predict(X_test) 

accuracy = svm_model.score(X_test, np.ravel(Y_test)) 
print ("Accuracy achieved = ",accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-640663fa1e88> in <module>
#       4 from sklearn.svm import SVC
#       5 svm_model = SVC(kernel = 'linear', C = 1).fit(X_train, Y_train)
# ----> 6 svm_predictions = svm_model.predict(X_test)
#       7
#       8 accuracy = svm_model.score(X_test, np.ravel(Y_test))
#
# NameError: name 'X_test' is not defined

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 17).fit(X_train, np.ravel(Y_train)) 
  
accuracy = knn.score(X_test, np.ravel(Y_test)) 
print ("Accuracy achieved = ",accuracy) 

y= np.ravel(Y_test)

knn_predictions = knn.predict(X_test)

#tabular representation of tested data

print ("\n====================\nResults\n====================\n") 
for i in range(len(Y_test)):
    if(y[i]==knn_predictions[i]):
        print("Correct Prediction for ",y[i])
    else:
        print("XXXXX Wrong XXXXX-----> correct: ",y[i],"   -----> predicted: ",knn_predictions[i])
